# %% [markdown]
# # model parameters

# %%
models parameters that are internal to model and model learns them on its own
e.g: in y=mx+c, model learn m and c on its own and these are model parameters

# %% [markdown]
# # model hyper parameters

# %%
vo parameters that are explicitly defined by the users to control the learning process, yani jab hm 
model ki brackets k ander shift+tab ko press krty hn to hmy bhhhttt saary parameters milty hn, un sab ko
hyper parameters bolty hn

--> thee hyper parameters are either selected by rule of thumb or by hit and trail method

# %% [markdown]
# # hyper parameter tuning

# %%
yani in hyper parameters ki value ko change kr kr k dekhna k kis pr achi accuracy ati h, kabhi 
deciosn tree m criterion entropy rkhty hn to kabhi gini index and it depends on data set, these
hyper parameters are tuned to decrease overfitting and to increase accuracy

# %%
but now, there are many advancements in ML these days, and via this, hyper parameters are tuned automatically

two functions are used for this:
    1- grid search CV
    2- ramdomized searchCV

# %% [markdown]
# # GridSearchCV

# %%
hmary jo bhi hyper parameters hoty hn , let's we have 2 hyperparameters, one is A having values (a,b)
and other is B having values (1,2,3) , then GridSearchCV will make a grid (like shown in following figure) , jis m
vo hr ek ek pr accuracy calculate kry ga, jesy phly y A ki value "a" rkh kr and B ki value "1" rkh kr dekhy ga k kia 
accuracy ai then "a" k sath hi B ki value "2" rkh kr then "3" rkh kr accuracy dekhy ga, then A ki value "b" rkh kr and 
isi trah B ki values 1, 2 , 3 rkh kr accuracy check kry ga, jis ki ziada ai us ko pich kry ga

---->> but prolem y ati h k jab bht bra dataset hota h to y bhhtt slow woek krta h q k y bar bar value change kr k hr
value pr model ko fit kr k accuracy check kr rha hota h so don't use GridSearchCV when dataset is big

# %%
from IPython.display import Image
Image(filename='grid_GridSearchCV.png', width=300, height=300)

# %% [markdown]
# # RandomizedSearch CV

# %%
y kuch selected pairs pr model ko fit kr k accuracy check krta h, is liye GridSearchCV ki nisbat fast hota h

---> selected pairs s murad y h k jesy uper vali picture and example k mutabik: total 6 pairs bny, a1,a2,a3, b1,b2,b3 
or grid valy n in sab pr accuarcy ko check kia lekin hm yha randomized m kuch selecetd pairs  bolyn gy, lets m n 3 pairs boly 
to y is grid m s kuch 3 ramdom pairs ko select kry ga and check accuracy and show us max accuarcy vala pair

----> DISADVANTAGE: may be vo pair jo randomly select nhi hua vo maximum accuaracy vala h
